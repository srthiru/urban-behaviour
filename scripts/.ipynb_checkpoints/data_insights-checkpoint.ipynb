# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import glob
import os
import numpy as np
import math
import datetime
import json

# %%
path = 'taxi data/taxi_zones_with_latlong.csv'
taxiZone = pd.read_csv(path)

taxiZone = taxiZone.drop(columns=['OBJECTID','Shape_Leng', 'Shape_Area'])
taxiZone.head()
# Out:
#                       zone  LocationID        borough        lat       long
# 0           Newark Airport           1            EWR -74.176786  40.689516
# 1              Jamaica Bay           2         Queens -73.826126  40.625724
# 2  Allerton/Pelham Gardens           3          Bronx -73.849479  40.865888
# 3            Alphabet City           4      Manhattan -73.977023  40.724152
# 4            Arden Heights           5  Staten Island -74.189930  40.550340

# %%
path = 'taxi data/all data/octoberWhole.csv'
october = pd.read_csv(path)

path = 'taxi data/all data/novemberWhole.csv'
november = pd.read_csv(path)


path = 'taxi data/all data/decemberWhole.csv'
december = pd.read_csv(path)

# %%
october.head()
# Out:
#                       zone  location  2018-10-01  2018-10-02  2018-10-03  \
# 0           Newark Airport         1        4485        3778        4450
# 1              Jamaica Bay         2           2           3           1
# 2  Allerton/Pelham Gardens         3         950         967        1001
# 3            Alphabet City         4        2635        3101        3122
# 4            Arden Heights         5         119         116         114
#
#    2018-10-04  2018-10-05  2018-10-06  2018-10-07  2018-10-08  ...  \
# 0        5780        5957        3958        5196        5055  ...
# 1           1           0           5           2           0  ...
# 2        1017        1092        1117        1027         848  ...
# 3        3400        3875        4932        4123        2774  ...
# 4         140         143         157         141          98  ...
#
#    2018-10-22  2018-10-23  2018-10-24  2018-10-25  2018-10-26  2018-10-27  \
# ...

# %%
november.head()
# Out:
#                       zone  location  2018-11-01  2018-11-02  2018-11-03  \
# 0           Newark Airport         1        4651        4910        3191
# 1              Jamaica Bay         2           2           2           1
# 2  Allerton/Pelham Gardens         3        1036        1172        1192
# 3            Alphabet City         4        3701        4162        5658
# 4            Arden Heights         5         150         149         181
#
#    2018-11-04  2018-11-05  2018-11-06  2018-11-07  2018-11-08  ...  \
# 0        5000        5462        4137        4147        5011  ...
# 1           3           5           4           5           3  ...
# 2        1074        1096        1045         918         982  ...
# 3        4339        3200        3238        3075        3414  ...
# 4         114         120         131         112         122  ...
#
#    2018-11-21  2018-11-22  2018-11-23  2018-11-24  2018-11-25  2018-11-26  \
# ...

# %%
december.head()
# Out:
#                       zone  location  2018-12-01  2018-12-02  2018-12-03  \
# 0           Newark Airport         1        3026        5851        4877
# 1              Jamaica Bay         2           0           0           0
# 2  Allerton/Pelham Gardens         3        1253        1033        1023
# 3            Alphabet City         4        5653        4829        3042
# 4            Arden Heights         5         157         129         104
#
#    2018-12-04  2018-12-05  2018-12-06  2018-12-07  2018-12-08  ...  \
# 0        4170        4770        5521        4925        3242  ...
# 1           1           5           2           2           3  ...
# 2         961        1000        1053        1187        1228  ...
# 3        3319        3496        3635        4573        6147  ...
# 4         126         154         138         172         180  ...
#
#    2018-12-22  2018-12-23  2018-12-24  2018-12-25  2018-12-26  2018-12-27  \
# ...

# %%
october = october.loc[:, october.columns!='location']
november = november.loc[:, november.columns!='location']
december = december.loc[:, december.columns!='location']

# %%
october = october.set_index('zone')
november = november.set_index('zone')
december = december.set_index('zone')

# %%
octT = october.T
novT = november.T
decT = december.T

# %%
x = np.arange(10)

fig = plt.figure(figsize=(20,10))

ax = plt.subplot(111)

# for i in range(5):
ax.plot(octT, label=octT.columns)

# Shrink current axis by 20%
box = ax.get_position()
ax.set_position([box.x0, box.y0, box.width * 0.9, box.height])

# Put a legend to the right of the current axis
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

xLabels = list(range(1,32))
ax.set_xticklabels(xLabels)
          
plt.show()
# Out:
# C:\Users\evladmin\AppData\Local\Temp/ipykernel_15692/2719648592.py:18: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(xLabels)
